# %%
def greet(name):
    print("Hello", name)
    
greet("Sujeet")
# Out:
# Hello Sujeet

# %%
#Add two Numbers

def add(a,b):
    print("Sum of two no. is:", a+b)

add(4,5)
# Out:
# Sum of two no. is: 9

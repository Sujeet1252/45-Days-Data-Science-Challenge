# %%
def function_name():
    print("Hello")

function_name();
# Out:
# Hello

# %%
def greet():
    print("Hello Data Science")

greet()
greet()
greet()
# Out:
# Hello Data Science
# Hello Data Science
# Hello Data Science

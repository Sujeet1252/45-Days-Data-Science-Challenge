# %%
def greet (name = " Student "):

    print ("Hello", name )

greet()
greet("Sujeet")
# Out:
# Hello  Student
# Hello Sujeet

# %%
def add(a, b=10):

    print(a+b)

add(5)
add(5,20)
# Out:
# 15
# 25

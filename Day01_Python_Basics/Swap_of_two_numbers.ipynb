# %%
a= int(input("first number:"))
b= int(input("Second number:"))
print ("before swapping value of a=",a,"and b=",b,"is")
a,b = b,a
print ("after swapping value of a=",a,"and b=",b,"is")
# Out:
# first number: 3
# Second number: 4
# before swapping value of a= 3 and b= 4 is
# after swapping value of a= 4 and b= 3 is

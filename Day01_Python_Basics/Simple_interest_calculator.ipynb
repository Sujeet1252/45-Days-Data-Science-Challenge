# %%
p = int(input("enter the principle"))
r = float(input("at what rate you want(%)"))
t = int(input("for how much time") )
print ("for", t,"years")
SI = (p*r*t)/100
print("simple interst will be", SI)
# Out:
# enter the principle 3
# at what rate you want(%) 3
# for how much time 3
# for 3 years
# simple interst will be 0.27

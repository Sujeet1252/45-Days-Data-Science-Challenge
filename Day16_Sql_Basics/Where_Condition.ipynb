# %%
import sqlite3

conn = sqlite3.connect("student.db")

cursor = conn.cursor()

cursor.execute("""
SELECT *
FROM Student
WHERE Marks > 85
""")

print(cursor.fetchall())
# Out:
# [(4, 'Ram', 90), (1, 'Sujeet', 90)]

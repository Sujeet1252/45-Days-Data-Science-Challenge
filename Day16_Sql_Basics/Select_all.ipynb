# %%
import sqlite3

conn = sqlite3.connect("student.db")

cursor = conn.cursor()

cursor.execute("""
SELECT * FROM Student
""")

for row in cursor:
    print(row)

conn.close()
# Out:
# (2, 'Rahul', 85)
# (3, 'Mohit', 80)
# (4, 'Ram', 90)
# (5, 'Sam', 75)
# (1, 'Sujeet', 90)

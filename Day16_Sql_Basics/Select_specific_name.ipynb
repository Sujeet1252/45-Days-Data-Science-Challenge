# %%
import sqlite3

conn = sqlite3.connect("student.db")

cursor = conn.cursor()

cursor.execute("""
SELECT Name FROM Student
""")

print(cursor.fetchall())
# Out:
# [('Rahul',), ('Mohit',), ('Ram',), ('Sam',), ('Sujeet',)]

# %%
import pandas as pd

data = {
    "Name": ["Sujeet", "Rahul", "Aman"],
    "Marks": [90, 85, 88]
}

df = pd.DataFrame(data)

print(df)
# Out:
#      Name  Marks
# 0  Sujeet     90
# 1   Rahul     85
# 2    Aman     88

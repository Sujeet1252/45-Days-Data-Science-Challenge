# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("multiple_linear_regression_dataset.csv")
dataset.head(3)
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580

# %%
dataset.shape
# Out:
# (20, 3)

# %%
plt.figure(figsize=(1,1))
sns.pairplot(data = dataset)
plt.show()

# %%
x = dataset[["age", "experience"]]
y = dataset["income"]

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(
    x,
    y,
    random_state = 42,
    test_size = 0.2
)

# %%
from sklearn.tree import DecisionTreeRegressor , plot_tree

dt = DecisionTreeRegressor(
    max_depth=4,
    min_samples_split=3,
    min_samples_leaf=2,
    random_state=42
)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, min_samples_leaf=2, min_samples_split=3,
#                       random_state=42)

# %%
dt.score(x_test,y_test)*100 , dt.score(x_train,y_train)*100
# Out:
# (18.254660748528273, 90.52851581203669)

# %%
plot_tree(dt)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

prediction = dt.predict(x_test)

print("MAE :", mean_absolute_error(y_test, prediction))
print("MSE :", mean_squared_error(y_test, prediction))
print("RMSE:", mean_squared_error(y_test, prediction) ** 0.5)
print("R2 :", r2_score(y_test, prediction))
# Out:
# MAE : 2383.333333333334
# MSE : 10053711.111111114
# RMSE: 3170.75875952604
# R2 : 0.18254660748528273

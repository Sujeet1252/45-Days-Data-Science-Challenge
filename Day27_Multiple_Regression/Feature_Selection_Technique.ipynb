# %% [markdown]
# # Feature Selection Technique
# Forward Elimination

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = sns.load_dataset("titanic")
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
x = dataset.iloc[:,:-1]
y = dataset["survived"]

# %%
x.shape
# Out:
# (891, 14)

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
fs = SequentialFeatureSelector(lr,k_features=14,forward =True)
fs.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 fs = SequentialFeatureSelector(lr,k_features=14,forward =True)
# ----> 2 fs.fit(x,y)
#
# File ~\anaconda3\Lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:553, in SequentialFeatureSelector.fit(self, X, y, groups, **fit_params)
#     550     search_set = prev_subset
#     551     must_include_set = self.fixed_features_group_set
# --> 553 k_idx, k_score, cv_scores = self._feature_selector(
#     554     search_set,
#     555     must_include_set,
#     556     X=X_,
#     557     y=y,
#     558     is_forward=self.forward,
#     559     groups=groups,
#     560     feature_groups=self.feature_groups_,
#     561     **fit_params,
#     562 )
#     564 k = len(k_idx)
#     565 # floating can lead to multiple same-sized subsets
#
# File ~\anaconda3\Lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py:800, in SequentialFeatureSelector._feature_selector(self, search_set, must_include_set, X, y, is_forward, groups, feature_groups, **fit_params)
#     796 n_jobs = min(self.n_jobs, n)
#     797 parallel = Parallel(
#     798     n_jobs=n_jobs, verbose=self.verbose, pre_dispatch=self.pre_dispatch
#     799 )
# --> 800 work = parallel(
#     801     delayed(_calc_score)(
#     802         self,
#     803         X,
#     804         y,
#     805         tuple(set(p) | must_include_set),
#     806         groups=groups,
#     807         feature_groups=feature_groups,
#     808         **fit_params,
#     809     )
#     810     for p in feature_explorer
#     811 )
#     813 all_avg_scores = []
#     814 all_cv_scores = []
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1918, in __call__(self, iterable)
#    1916         self.print_progress()
#    1917         yield res
# -> 1918         self._nb_consumed += 1
#    1919 except BaseException:
#    1920     self._exception = True
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1847, in _get_sequential_output(self, iterable)
#    1846 def _raise_error_fast(self):
# -> 1847     """If we are aborting, raise if a job caused an error."""
#    1849     # Find the first job whose status is TASK_ERROR if it exists.
#    1850     with self._lock:
#
# File ~\anaconda3\Lib\site-packages\mlxtend\feature_selection\utilities.py:100, in _calc_score(selector, X, y, indices, groups, feature_groups, **fit_params)
#      97 param_name = "fit_params" if sklearn_version < "1.4" else "params"
#      99 if selector.cv:
# --> 100     scores = cross_val_score(
#     101         selector.est_,
#     102         X[:, IDX],
#     103         y,
#     104         groups=groups,
#     105         cv=selector.cv,
#     106         scoring=selector.scorer,
#     107         n_jobs=1,
#     108         pre_dispatch=selector.pre_dispatch,
#     109         **{param_name: fit_params},
#     110     )
#     111 else:
#     112     selector.est_.fit(X[:, IDX], y, **fit_params)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in wrapper(*args, **kwargs)
#     208 validate_parameter_constraints(
#     209     parameter_constraints, params, caller_name=func.__qualname__
#     210 )
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
# --> 216         )
#     217     ):
#     218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:684, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     650     cv_results = cross_validate(
#     651         estimator=estimator,
#     652         X=X,
#    (...)    661         error_score=error_score,
#     662     )
#     663     return cv_results["test_score"]
#     666 def _fit_and_score(
#     667     estimator,
#     668     X,
#     669     y,
#     670     *,
#     671     scorer,
#     672     train,
#     673     test,
#     674     verbose,
#     675     parameters,
#     676     fit_params,
#     677     score_params,
#     678     return_train_score=False,
#     679     return_parameters=False,
#     680     return_n_test_samples=False,
#     681     return_times=False,
#     682     return_estimator=False,
#     683     split_progress=None,
# --> 684     candidate_progress=None,
#     685     error_score=np.nan,
#     686     caller=None,
#     687     callback_ctx=None,
#     688 ):
#     689     """Fit estimator and compute scores for a given dataset split.
#     690
#     691     Parameters
#    (...)    783             Traceback str if the fit failed, None if the fit succeeded.
#     784     """
#     785     xp, _ = get_namespace(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in wrapper(*args, **kwargs)
#     208 validate_parameter_constraints(
#     209     parameter_constraints, params, caller_name=func.__qualname__
#     210 )
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
# --> 216         )
#     217     ):
#     218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:431, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     426 def _insert_error_scores(results, error_score):
#     427     """Insert error in `results` by replacing them inplace with `error_score`.
#     428
#     429     This only applies to multimetric scores because `_fit_and_score` will
#     430     handle the single metric case.
# --> 431     """
#     432     successful_score = None
#     433     failed_indices = []
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:517, in _warn_or_raise_about_fit_failures(results, error_score)
#     481             some_fits_failed_message = (
#     482                 f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     483                 "The score on these train-test partitions for these parameters"
#    (...)    487                 f"Below are more details about the failures:\n{fit_errors_summary}"
#     488             )
#     489             warnings.warn(some_fits_failed_message, FitFailedWarning)
#     492 @validate_params(
#     493     {
#     494         "estimator": [HasMethods("fit")],
#     495         "X": ["array-like", "sparse matrix"],
#     496         "y": ["array-like", None],
#     497         "groups": ["array-like", None],
#     498         "scoring": [StrOptions(set(get_scorer_names())), callable, None],
#     499         "cv": ["cv_object"],
#     500         "n_jobs": [Integral, None],
#     501         "verbose": ["verbose"],
#     502         "params": [dict, None],
#     503         "pre_dispatch": [Integral, str, None],
#     504         "error_score": [StrOptions({"raise"}), Real],
#     505     },
#     506     prefer_skip_nested_validation=False,  # estimator is not validated yet
#     507 )
#     508 def cross_val_score(
#     509     estimator,
#     510     X,
#     511     y=None,
#     512     *,
#     513     groups=None,
#     514     scoring=None,
#     515     cv=None,
#     516     n_jobs=None,
# --> 517     verbose=0,
#     518     params=None,
#     519     pre_dispatch="2*n_jobs",
#     520     error_score=np.nan,
#     521 ):
#     522     """Evaluate a score by cross-validation.
#     523
#     524     Read more in the :ref:`User Guide <cross_validation>`.
#    (...)    645     [0.3315057  0.08022103 0.03531816]
#     646     """
#     647     # To ensure multimetric format is not supported
#
# ValueError:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     test_scores = {name: error_score for name in scorer._scorers}
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1222, in fit
#     Notes
#
#     ...<7 lines>...
#     cases. See :ref:`differences from liblinear <liblinear_differences>`
#     ^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2961, in validate_data
#     y : array-like of shape (n_samples,), default='no_validation'
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1370, in check_X_y
#
#
#     ...<14 lines>...
#             .. versionadded:: 1.2
#
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1055, in check_array
#     )
#
#   File "C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py", line 839, in _asarray_with_order
#     return (xp.mean if normalize else xp.sum)(a, axis=axis)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: could not convert string to float: 'male'

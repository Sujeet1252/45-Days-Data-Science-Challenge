# %%
import pandas as pd

movies = {
    "Movie": [
        "Jawan",
        "Pathaan",
        "KGF 2",
        "Dangal",
        "RRR",
        "3 Idiots",
        "Animal"
    ],

    "Genre": [
        "Action",
        "Action",
        "Action",
        "Drama",
        "Action",
        "Comedy",
        "Drama"
    ],

    "Rating": [
        8.1,
        7.8,
        8.5,
        8.4,
        8.2,
        8.4,
        7.9
    ],

    "Revenue": [
        1150,
        1050,
        1250,
        2000,
        1350,
        450,
        900
    ]
}

df = pd.DataFrame(movies)

print("=" * 50)
print("       MOVIE ANALYTICS DASHBOARD")
print("=" * 50)

print("\nMovie Dataset")
print(df)

# Basic Statistics
print("\n===== BASIC ANALYSIS =====")

print("Total Movies        :", len(df))

print("Average Rating      :",
      round(df["Rating"].mean(), 2))

print("Highest Rating      :",
      df["Rating"].max())

print("Lowest Rating       :",
      df["Rating"].min())

print("Highest Revenue     :",
      df["Revenue"].max())

print("Lowest Revenue      :",
      df["Revenue"].min())

# Highest Rated Movie
top_movie = df.loc[df["Rating"].idxmax()]

print("\nHighest Rated Movie")
print(top_movie)

# Highest Revenue Movie
revenue_movie = df.loc[df["Revenue"].idxmax()]

print("\nHighest Revenue Movie")
print(revenue_movie)

# Top 3 Movies
print("\n===== TOP 3 MOVIES =====")

top3 = df.sort_values(
    by="Rating",
    ascending=False
).head(3)

print(top3)

# Genre Analysis
print("\n===== GENRE ANALYSIS =====")

genre_rating = df.groupby("Genre")["Rating"].mean()

print("\nAverage Rating by Genre")
print(genre_rating)

genre_revenue = df.groupby("Genre")["Revenue"].sum()

print("\nRevenue by Genre")
print(genre_revenue)

print("\nMost Profitable Genre")

print(genre_revenue.idxmax())

print("=" * 50)
# Out:
# ==================================================
#        MOVIE ANALYTICS DASHBOARD
# ==================================================
#
# Movie Dataset
#       Movie   Genre  Rating  Revenue
# 0     Jawan  Action     8.1     1150
# 1   Pathaan  Action     7.8     1050
# 2     KGF 2  Action     8.5     1250
# 3    Dangal   Drama     8.4     2000
# 4       RRR  Action     8.2     1350
# 5  3 Idiots  Comedy     8.4      450
# 6    Animal   Drama     7.9      900
#
# ===== BASIC ANALYSIS =====
# Total Movies        : 7
# Average Rating      : 8.19
# Highest Rating      : 8.5
# Lowest Rating       : 7.8
# Highest Revenue     : 2000
# Lowest Revenue      : 450
#
# Highest Rated Movie
# Movie       KGF 2
# Genre      Action
# Rating        8.5
# Revenue      1250
# Name: 2, dtype: object
#
# Highest Revenue Movie
# Movie      Dangal
# Genre       Drama
# Rating        8.4
# Revenue      2000
# Name: 3, dtype: object
#
# ===== TOP 3 MOVIES =====
#       Movie   Genre  Rating  Revenue
# 2     KGF 2  Action     8.5     1250
# 5  3 Idiots  Comedy     8.4      450
# 3    Dangal   Drama     8.4     2000
#
# ===== GENRE ANALYSIS =====
#
# Average Rating by Genre
# Genre
# Action    8.15
# Comedy    8.40
# Drama     8.15
# Name: Rating, dtype: float64
#
# Revenue by Genre
# Genre
# Action    4800
# Comedy     450
# Drama     2900
# Name: Revenue, dtype: int64
#
# Most Profitable Genre
# Action
# ==================================================

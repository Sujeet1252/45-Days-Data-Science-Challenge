# %%
import pandas as pd

employees = {
    "Name": ["Aman","Rahul","Priya","Neha","Rohit","Simran","Karan"],
    "Department": ["IT","HR","IT","Finance","HR","Finance","IT"],
    "Salary": [50000,40000,60000,70000,45000,80000,55000],
    "Experience": [2,1,4,6,3,8,5]
}

df = pd.DataFrame(employees)

print("="*40)
print("    Employee Analytics Dashboard")
print("="*40)

print("\n== Employee Datasets ==")
print(df)

print("\n=== Total Employeees ===")
print("Total Employees is :",df["Name"].count())

print("Average Salary is :",df["Salary"].mean())
print("Highest Salary is :",df["Salary"].max())
print("Lowest Salary is : ",df["Salary"].min())

print("\n=== Average Salary by Department ===")
print(df.groupby("Department")["Salary"].mean())

print("\n=== Total Salary by Department ===")
print(df.groupby("Department")["Salary"].sum())

print("\n=== Employee Count by Department ===")
print(df.groupby("Department")["Name"].count())

print("\n=== Most Experienced Employee ===")
print(df.loc[df["Experience"].idxmax()])

print("\n=== Average Experience ===")
print(df["Experience"].mean())

print("\n=== Highest Paid Employee ===")
print(df.loc[df["Salary"].idxmax()])

print("\n===Top 3 Salaries ===")
print(df.nlargest(3,"Salary"))
# Out:
# ========================================
#     Employee Analytics Dashboard
# ========================================
#
# == Employee Datasets ==
#      Name Department  Salary  Experience
# 0    Aman         IT   50000           2
# 1   Rahul         HR   40000           1
# 2   Priya         IT   60000           4
# 3    Neha    Finance   70000           6
# 4   Rohit         HR   45000           3
# 5  Simran    Finance   80000           8
# 6   Karan         IT   55000           5
#
# === Total Employeees ===
# Total Employees is : 7
# Average Salary is : 57142.857142857145
# Highest Salary is : 80000
# Lowest Salary is :  40000
#
# === Average Salary by Department ===
# Department
# Finance    75000.0
# HR         42500.0
# IT         55000.0
# Name: Salary, dtype: float64
#
# === Total Salary by Department ===
# Department
# Finance    150000
# HR          85000
# IT         165000
# Name: Salary, dtype: int64
#
# === Employee Count by Department ===
# Department
# Finance    2
# HR         2
# IT         3
# Name: Name, dtype: int64
#
# === Most Experienced Employee ===
# Name           Simran
# Department    Finance
# Salary          80000
# Experience          8
# Name: 5, dtype: object
#
# === Average Experience ===
# 4.142857142857143
#
# === Highest Paid Employee ===
# Name           Simran
# Department    Finance
# Salary          80000
# Experience          8
# Name: 5, dtype: object
#
# ===Top 3 Salaries ===
#      Name Department  Salary  Experience
# 5  Simran    Finance   80000           8
# 3    Neha    Finance   70000           6
# 2   Priya         IT   60000           4

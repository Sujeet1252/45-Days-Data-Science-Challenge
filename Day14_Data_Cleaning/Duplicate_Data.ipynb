# %%
import pandas as pd

data = {
    "Name": ["Aman", "Rahul", "Aman"],
    "Salary": [50000, 60000, 50000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Salary
# 0   Aman   50000
# 1  Rahul   60000
# 2   Aman   50000

# %%
# Find Duplicates

print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
#Removes Duplicated

df = df.drop_duplicates()
print(df)
# Out:
#     Name  Salary
# 0   Aman   50000
# 1  Rahul   60000

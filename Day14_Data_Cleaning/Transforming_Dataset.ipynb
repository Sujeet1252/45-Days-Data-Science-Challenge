# %%
import pandas as pd

employees = {
    "Emp_Name": ["  Sujeet  ", "Rahul", "AMAN", "priya"],
    "Salary": [45000.0, 55000.0, 60000.0, 50000.0],
    "Department": ["IT", "HR", "IT", "Finance"]
}

df = pd.DataFrame(employees)

print(df)
# Out:
#      Emp_Name   Salary Department
# 0    Sujeet    45000.0         IT
# 1       Rahul  55000.0         HR
# 2        AMAN  60000.0         IT
# 3       priya  50000.0    Finance

# %%
df.rename(columns={"Emp_Name":"Name"}, inplace=True)

print(df)
# Out:
#          Name   Salary Department
# 0    Sujeet    45000.0         IT
# 1       Rahul  55000.0         HR
# 2        AMAN  60000.0         IT
# 3       priya  50000.0    Finance

# %%
print(df.dtypes)

df["Salary"] = df["Salary"].astype(str)

print(df.dtypes)
# Out:
# Name              str
# Salary        float64
# Department        str
# dtype: object
# Name          str
# Salary        str
# Department    str
# dtype: object

# %%
df["Salary"] = df["Salary"].astype(float)

df["Salary"] = df["Salary"].astype(int)

print(df)
# Out:
#          Name  Salary Department
# 0    Sujeet     45000         IT
# 1       Rahul   55000         HR
# 2        AMAN   60000         IT
# 3       priya   50000    Finance

# %%
df["Department"] = df["Department"].replace({
    "IT":"Technology",
    "HR":"Human Resource"
})

print(df)
# Out:
#          Name  Salary      Department
# 0    Sujeet     45000      Technology
# 1       Rahul   55000  Human Resource
# 2        AMAN   60000      Technology
# 3       priya   50000         Finance

# %%
df["Name"] = df["Name"].str.strip()
df["Name"] = df["Name"].str.title()

print(df)
# Out:
#      Name  Salary      Department
# 0  Sujeet   45000      Technology
# 1   Rahul   55000  Human Resource
# 2    Aman   60000      Technology
# 3   Priya   50000         Finance

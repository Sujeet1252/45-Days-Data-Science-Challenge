# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Aman", "Rahul", None, "Priya", "Neha"],
    "Age": [23, np.nan, 25, 22, 23],
    "Salary": [50000, 60000, np.nan, 70000, 50000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name   Age   Salary
# 0   Aman  23.0  50000.0
# 1  Rahul   NaN  60000.0
# 2    NaN  25.0      NaN
# 3  Priya  22.0  70000.0
# 4   Neha  23.0  50000.0

# %%
#Check Missing VAlues

print(df.isnull())
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False  False   False
# 4  False  False   False

# %%
#Count Missing VAlues

print(df.isnull().sum())
# Out:
# Name      1
# Age       1
# Salary    1
# dtype: int64

# %%
#Removes rows containing missing Values

df.dropna()
# Out:
#     Name   Age   Salary
# 0   Aman  23.0  50000.0
# 3  Priya  22.0  70000.0
# 4   Neha  23.0  50000.0

# %%
#Fill Age with Average

df["Age"] = df["Age"].fillna(df["Age"].mean())
print(df)
# Out:
#     Name    Age   Salary
# 0   Aman  23.00  50000.0
# 1  Rahul  23.25  60000.0
# 2    NaN  25.00      NaN
# 3  Priya  22.00  70000.0
# 4   Neha  23.00  50000.0

# %%
#Fill Salary with Average

df["Salary"] = df["Salary"].fillna(df["Salary"].mean())
print(df)
# Out:
#     Name    Age   Salary
# 0   Aman  23.00  50000.0
# 1  Rahul  23.25  60000.0
# 2    NaN  25.00  57500.0
# 3  Priya  22.00  70000.0
# 4   Neha  23.00  50000.0

# %%
#Fill Name with Unknown

df["Name"] = df["Name"].fillna("Unknown")
print(df)
# Out:
#       Name    Age   Salary
# 0     Aman  23.00  50000.0
# 1    Rahul  23.25  60000.0
# 2  Unknown  25.00  57500.0
# 3    Priya  22.00  70000.0
# 4     Neha  23.00  50000.0

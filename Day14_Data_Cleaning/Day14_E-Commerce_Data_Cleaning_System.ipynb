# %%
import pandas as pd
import numpy as np

data = {
    "Product": [
        "Laptop",
        "Phone",
        None,
        "Laptop",
        "Tablet"
    ],

    "Price": [
        50000,
        np.nan,
        25000,
        50000,
        18000
    ],

    "Category": [
        "Electronics",
        "Electronics",
        None,
        "Electronics",
        "Electronics"
    ]
}

df = pd.DataFrame(data)

print("==" * 20)
print("    E-Commerce Data Cleaning System")
print("==" *20)
print(df)

print("\n Detect Missing Values")
print(df.isnull())

print("\n Fill Missing Product Name")
df["Product"]= df["Product"].fillna("Unknown Product")
print(df)

print("Fill Missing Price")
df["Price"] = df["Price"].fillna(df["Price"].mean())
print(df)

print("\n Fill Missing Category")
df["Category"] = df["Category"].fillna("Unknown Category")

print("\nRemove Duplicates")
print(df.drop_duplicates())
# Out:
# ========================================
#     E-Commerce Data Cleaning System
# ========================================
#   Product    Price     Category
# 0  Laptop  50000.0  Electronics
# 1   Phone      NaN  Electronics
# 2     NaN  25000.0          NaN
# 3  Laptop  50000.0  Electronics
# 4  Tablet  18000.0  Electronics
#
#  Detect Missing Values
#    Product  Price  Category
# 0    False  False     False
# 1    False   True     False
# 2     True  False      True
# 3    False  False     False
# 4    False  False     False
#
#  Fill Missing Product Name
#            Product    Price     Category
# 0           Laptop  50000.0  Electronics
# 1            Phone      NaN  Electronics
# 2  Unknown Product  25000.0          NaN
# 3           Laptop  50000.0  Electronics
# 4           Tablet  18000.0  Electronics
# Fill Missing Price
#            Product    Price     Category
# 0           Laptop  50000.0  Electronics
# 1            Phone  35750.0  Electronics
# 2  Unknown Product  25000.0          NaN
# 3           Laptop  50000.0  Electronics
# 4           Tablet  18000.0  Electronics
#
#  Fill Missing Category
#
# Remove Duplicates
#            Product    Price          Category
# 0           Laptop  50000.0       Electronics
# 1            Phone  35750.0       Electronics
# 2  Unknown Product  25000.0  Unknown Category
# 4           Tablet  18000.0       Electronics

# %%
string = input("Enter the string :")

reverse_string = string[::-1]

print("Reverse of String is :", reverse_string)
# Out:
# Enter the string : Sujeet
# Reverse of String is : teejuS

# %%
#Using for loop

string = input("Enter the string :")

reverse_string = ""

for char in string:
    reverse_string = char + reverse_string

print("Reversed string is : ", reverse_string )
# Out:
# Enter the string : Sujeet
# Reversed string is :  teejuS

# %%
# ====================
# Text Analyzer System
# ====================

print("===== Text Anayzer System =====")

string = input("Enter the string :")

char_count = len(string)

word_count = len(string.split())

uppercase_string = string.upper()

lowercase_string = string.lower()

vowels = 0
consonants = 0
uppercase = 0
lowercase = 0

for char in string:

    if char in "AEIOUaeiou":
        vowels += 1

    elif char.isalpha():
        consonants += 1

    if char.isupper():
        uppercase += 1

    elif char.islower():
        lowercase += 1
        
frequency = {}

for char in string:

    if char != " ":

        if char in frequency:
            frequency[char] += 1
        else:
            frequency[char] = 1

print("\n===== ANALYSIS REPORT =====")

print(f"Total Characters : {char_count}")
print(f"Total Words      : {word_count}")
print(f"Total Vowels     : {vowels}")
print(f"Total Consonants : {consonants}")
print(f"Uppercase Letters: {uppercase_string}")
print(f"Lowercase Letters: {lowercase_string}")

print("\nCharacter Frequency:")

for char, count in frequency.items():
    print(f"{char} = {count}")

print("\n===== END OF REPORT =====")
# Out:
# ===== Text Anayzer System =====
# Enter the string : There Is A Lion In A jungle
# ===== ANALYSIS REPORT =====
# Total Characters : 27
# Total Words      : 7
# Total Vowels     : 10
# Total Consonants : 11
# Uppercase Letters: THERE IS A LION IN A JUNGLE
# Lowercase Letters: there is a lion in a jungle
#
# Character Frequency:
# T = 1
# h = 1
# e = 3
# r = 1
# I = 2
# s = 1
# A = 2
# L = 1
# i = 1
# o = 1
# n = 3
# j = 1
# u = 1
# g = 1
# l = 1
#
# ===== END OF REPORT =====

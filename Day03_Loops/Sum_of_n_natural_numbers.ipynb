# %%
n = int(input("Enter the value of n"))
sum_n= n*(n+1)//2
print(sum_n)
# Out:
# Enter the value of n 10
# 55

# %%
n = int(input("Enter the value of n"))

i=1
total=0

while i <= n:
    total += i
    i += 1

print("sum=",total)
# Out:
# Enter the value of n 10
# sum= 55

# %%
n = int(input("Enter the value of n"))

total=0

for i in range (1, n+1):
    total+= i

print("sum = ", total)
# Out:
# Enter the value of n 10
# sum =  55

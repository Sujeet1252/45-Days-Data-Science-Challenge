# %%
set1 = {25,12,23,14,15,16,25,24,36}
print("\n Set One is :" , set1)

set2 = {12,17,18,19,13,24,28,29,35}
print("\n Set Two is :", set2)

result = set1.difference(set2)

print("\n Difference of Set1 - Set2 :", result)

result= set2.difference(set1)

print("\n Difference of Set2 - Set1 :", result)
# Out:
#  Set One is : {36, 12, 14, 15, 16, 23, 24, 25}
#
#  Set Two is : {35, 12, 13, 17, 18, 19, 24, 28, 29}
#
#  Difference of Set1 - Set2 : {36, 14, 15, 16, 23, 25}
#
#  Difference of Set2 - Set1 : {35, 13, 17, 18, 19, 28, 29}

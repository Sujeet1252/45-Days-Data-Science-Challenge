# %%
set = {12,14,15,14,12,13,14,15,17,10}

print("Original Set is :", set)

#adds an value
set.add(20)
set.add(35)
set.add(45)

print("After adding : ", set)

#removes a values
set.remove(15)
set.remove(13)

print("After removing :",set)
# Out:
# Original Set is : {17, 10, 12, 13, 14, 15}
# After adding :  {10, 12, 13, 14, 15, 17, 20, 35, 45}
# After removing : {10, 12, 14, 17, 20, 35, 45}

# %%
names = {'Ram','Sujeet','Rohan','Ram','Sujeet','Mohit','Rohan'}

print(names)
# Out:
# {'Mohit', 'Sujeet', 'Rohan', 'Ram'}

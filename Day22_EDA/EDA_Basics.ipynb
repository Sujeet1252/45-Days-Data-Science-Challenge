# %%
import pandas as pd

data = {
    "Age":[21,22,23,24,25],
    "Salary":[25000,20000,15000,40000,55000],
    "Experience":[1,2,3,4,5]
}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    Age  Salary  Experience
# 0   21   25000           1
# 1   22   20000           2
# 2   23   15000           3
# 3   24   40000           4
# 4   25   55000           5

# %%
df.corr()
# Out:
#                  Age    Salary  Experience
# Age         1.000000  0.773389    1.000000
# Salary      0.773389  1.000000    0.773389
# Experience  1.000000  0.773389    1.000000

# %%
import matplotlib.pyplot as plt

df["Salary"].hist()

plt.show()

# %%
import seaborn as sns

sns.boxplot(x=df["Salary"])
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

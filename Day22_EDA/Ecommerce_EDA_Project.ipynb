# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

data = {
    "Product": [
        "Laptop","Phone","Tablet","Mouse",
        "Keyboard","Laptop","Phone","Tablet",
        "Mouse","Keyboard"
    ],

    "Category": [
        "Electronics","Electronics","Electronics",
        "Accessories","Accessories",
        "Electronics","Electronics","Electronics",
        "Accessories","Accessories"
    ],

    "Price": [
        50000,25000,18000,800,1500,
        50000,25000,18000,800,1500
    ],

    "Quantity": [
        5,8,4,20,15,
        3,5,2,7,8
    ],

    "Rating": [
        4.5,4.2,4.1,3.8,4.0,
        4.6,4.3,4.0,3.9,4.1
    ],

    "City": [
        "Delhi","Mumbai","Delhi","Lucknow","Delhi",
        "Mumbai","Delhi","Lucknow","Delhi","Mumbai"
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Product     Category  Price  Quantity  Rating     City
# 0    Laptop  Electronics  50000         5     4.5    Delhi
# 1     Phone  Electronics  25000         8     4.2   Mumbai
# 2    Tablet  Electronics  18000         4     4.1    Delhi
# 3     Mouse  Accessories    800        20     3.8  Lucknow
# 4  Keyboard  Accessories   1500        15     4.0    Delhi
# 5    Laptop  Electronics  50000         3     4.6   Mumbai
# 6     Phone  Electronics  25000         5     4.3    Delhi
# 7    Tablet  Electronics  18000         2     4.0  Lucknow
# 8     Mouse  Accessories    800         7     3.9    Delhi
# 9  Keyboard  Accessories   1500         8     4.1   Mumbai

# %%
df.shape
# Out:
# (10, 6)

# %%
df.columns
# Out:
# Index(['Product', 'Category', 'Price', 'Quantity', 'Rating', 'City'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   10 non-null     str
#  1   Category  10 non-null     str
#  2   Price     10 non-null     int64
#  3   Quantity  10 non-null     int64
#  4   Rating    10 non-null     float64
#  5   City      10 non-null     str
# dtypes: float64(1), int64(2), str(3)
# memory usage: 839.0 bytes

# %%
df.describe()
# Out:
#               Price   Quantity     Rating
# count     10.000000  10.000000  10.000000
# mean   19060.000000   7.700000   4.150000
# std    19064.055765   5.657836   0.254951
# min      800.000000   2.000000   3.800000
# 25%     1500.000000   4.250000   4.000000
# 50%    18000.000000   6.000000   4.100000
# 75%    25000.000000   8.000000   4.275000
# max    50000.000000  20.000000   4.600000

# %%
df.isnull().sum()
# Out:
# Product     0
# Category    0
# Price       0
# Quantity    0
# Rating      0
# City        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Revenue"] = df["Price"] * df["Quantity"]
print("Total Revenue is :" , df["Revenue"].sum())
print("Average Revenue is :" , df["Revenue"].mean())
# Out:
# Total Revenue is : 889100
# Average Revenue is : 88910.0

# %%
print("Most Expensive Product is :")
df.loc[df["Price"].idxmax()]
# Out:
# Most Expensive Product is :
# Product          Laptop
# Category    Electronics
# Price             50000
# Quantity              5
# Rating              4.5
# City              Delhi
# Revenue          250000
# Name: 0, dtype: object

# %%
print("Highest Revenue Product is :")
df.loc[df["Revenue"].idxmax()]
# Out:
# Highest Revenue Product is :
# Product          Laptop
# Category    Electronics
# Price             50000
# Quantity              5
# Rating              4.5
# City              Delhi
# Revenue          250000
# Name: 0, dtype: object

# %%
print("Revenue by category :")
print(df.groupby("Category")["Revenue"].sum())
print("\nRevenue by city :")
print(df.groupby("City")["Revenue"].sum())
# Out:
# Revenue by category :
# Category
# Accessories     56100
# Electronics    833000
# Name: Revenue, dtype: int64
#
# Revenue by city :
# City
# Delhi      475100
# Lucknow     52000
# Mumbai     362000
# Name: Revenue, dtype: int64

# %%
plt.hist(df["Price"],bins=5,color="skyblue",edgecolor="black")
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.grid(axis="y",alpha=0.7)
plt.show()

# %%
df.groupby("Product")["Revenue"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Product'>

# %%
sns.boxplot(x=df["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
sns.heatmap(df.corr(numeric_only=True),
           annot = True)
# Out:
# <Axes: >

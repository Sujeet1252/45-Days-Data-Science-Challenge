# %% [markdown]
# # Features and Target

# %%
import pandas as pd
df=pd.DataFrame({'Area':[1000,1200],'Bedrooms':[2,2],'Age':[10,8],'Price':[35,40]})
X=df[['Area','Bedrooms','Age']]
y=df['Price']
print(X)
print(y)

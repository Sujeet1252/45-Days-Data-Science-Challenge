# %% [markdown]
# # Machine Learning Basics

# %%
import pandas as pd
import numpy as np
import kagglehub
import os 

path = kagglehub.dataset_download("architsharma01/loan-approval-prediction-dataset")

print("Path to dataset files:", path)
print(os.listdir(path))
# Out:
# Downloading to C:\Users\ASUS\.cache\kagglehub\datasets\architsharma01\loan-approval-prediction-dataset\1.archive...
# 100%|██████████████████████████████████████████████████████████████████████████████| 80.6k/80.6k [00:00<00:00, 201kB/s]
# Extracting files...
# Path to dataset files: C:\Users\ASUS\.cache\kagglehub\datasets\architsharma01\loan-approval-prediction-dataset\versions\1
# ['loan_approval_dataset.csv']

# %%
df = pd.read_csv(os.path.join(path,"loan_approval_dataset.csv"))
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   str
#  3    self_employed             4269 non-null   str
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   str
# dtypes: int64(10), str(3)
# memory usage: 531.6 KB

# %%
df.select_dtypes(include="int64").columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' income_annum', ' loan_amount',
#        ' loan_term', ' cibil_score', ' residential_assets_value',
#        ' commercial_assets_value', ' luxury_assets_value',
#        ' bank_asset_value'],
#       dtype='str')

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="mean")
ar =si.fit_transform(df[['loan_id', ' no_of_dependents', ' income_annum', ' loan_amount',
       ' loan_term', ' cibil_score', ' residential_assets_value',
       ' commercial_assets_value', ' luxury_assets_value',
       ' bank_asset_value']])

# %%
new_dataset = pd.DataFrame(ar,columns = df.select_dtypes(include="int64").columns)

# %%
new_dataset.head()
# Out:
#    loan_id   no_of_dependents   income_annum   loan_amount   loan_term  \
# 0      1.0                2.0      9600000.0    29900000.0        12.0
# 1      2.0                0.0      4100000.0    12200000.0         8.0
# 2      3.0                3.0      9100000.0    29700000.0        20.0
# 3      4.0                3.0      8200000.0    30700000.0         8.0
# 4      5.0                5.0      9800000.0    24200000.0        20.0
#
#     cibil_score   residential_assets_value   commercial_assets_value  \
# 0         778.0                  2400000.0                17600000.0
# 1         417.0                  2700000.0                 2200000.0
# 2         506.0                  7100000.0                 4500000.0
# 3         467.0                 18200000.0                 3300000.0
# 4         382.0                 12400000.0                 8200000.0
#
#     luxury_assets_value   bank_asset_value
# 0            22700000.0          8000000.0
# 1             8800000.0          3300000.0
# 2            33300000.0         12800000.0
# 3            23300000.0          7900000.0
# 4            29400000.0          5000000.0

# %%
df.columns.tolist()
# Out:
# ['loan_id',
#  ' no_of_dependents',
#  ' education',
#  ' self_employed',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value',
#  ' loan_status']

# %%
df[" loan_term"].mean()
# Out:
# np.float64(10.900445069102835)

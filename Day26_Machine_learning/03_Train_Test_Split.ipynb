# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
df=pd.DataFrame({'A':[1,2,3,4],'B':[5,6,7,8],'Y':[9,10,11,12]})
X=df[['A','B']];y=df['Y']
print(train_test_split(X,y,test_size=0.25,random_state=42))

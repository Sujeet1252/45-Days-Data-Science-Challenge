# %%
import pandas as pd


Employee = {
    "Name" : ["Sujeet","Ram","Sam","Rohan","Sumit"],
    "Salary" : [35000,25000,30000,32000,28000],
    "City" : ["Varanasi","dehradun","Delhi","Mumbai","Jaipur"]
}

df = pd.DataFrame(Employee)

print(df)

print("\n== Display Name Column ==")
print(df["Name"])

print("\n== Display Salary Column ==")
print(df["Salary"])

print("\n== Display Multiple Columns ==")
print(df[["Name","Salary"]])

print("\n== Display First Three rows ==")
# Out:
#      Name  Salary      City
# 0  Sujeet   35000  Varanasi
# 1     Ram   25000  dehradun
# 2     Sam   30000     Delhi
# 3   Rohan   32000    Mumbai
# 4   Sumit   28000    Jaipur
#
# == Display Name Column ==
# 0    Sujeet
# 1       Ram
# 2       Sam
# 3     Rohan
# 4     Sumit
# Name: Name, dtype: str
#
# == Display Salary Column ==
# 0    35000
# 1    25000
# 2    30000
# 3    32000
# 4    28000
# Name: Salary, dtype: int64
#
# == Display Multiple Columns ==
#      Name  Salary
# 0  Sujeet   35000
# 1     Ram   25000
# 2     Sam   30000
# 3   Rohan   32000
# 4   Sumit   28000
#
# == Display First Three rows ==
#      Name  Salary      City
# 0  Sujeet   35000  Varanasi
# 1     Ram   25000  dehradun
# 2     Sam   30000     Delhi

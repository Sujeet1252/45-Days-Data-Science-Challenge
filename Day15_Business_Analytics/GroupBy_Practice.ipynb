# %%
import pandas as pd

data = {
    "Product": [
        "Laptop", "Phone", "Tablet", "Mouse", "Keyboard",
        "Monitor", "Printer", "Headphones", "Speaker", "Camera"
    ],

    "Category": [
        "Electronics", "Electronics", "Electronics",
        "Accessories", "Accessories",
        "Electronics", "Office",
        "Accessories", "Accessories", "Electronics"
    ],

    "Customer": [
        "Aman", "Rahul", "Priya", "Aman", "Rohit",
        "Rahul", "Priya", "Neha", "Aman", "Rohit"
    ],

    "City": [
        "Delhi", "Mumbai", "Delhi", "Jaipur", "Mumbai",
        "Delhi", "Pune", "Jaipur", "Delhi", "Pune"
    ],

    "Price": [
        50000, 25000, 18000, 800, 1500,
        12000, 10000, 2500, 3500, 40000
    ],

    "Quantity": [
        5, 8, 4, 20, 15,
        6, 3, 10, 7, 2
    ]
}

df = pd.DataFrame(data)

# Revenue Column
df["Revenue"] = df["Price"] * df["Quantity"]

print(df)

print("\n Revenue by Category")
print("-"*25)
print(df.groupby("Category")["Revenue"].sum())

print("\n Revenue By City")
print("-"*25)
print(df.groupby("City")["Revenue"].sum())

print("\n Revenue by Customers")
print("-"*25)
print(df.groupby("Customer")["Revenue"].sum())

print("\nProduct count by category")
print("-"*25)
print(df.groupby("Category")["Product"].count())

print("\n Orders per City")
print("-"*25)
print(df.groupby("City")["Product"].count())
# Out:
#       Product     Category Customer    City  Price  Quantity  Revenue
# 0      Laptop  Electronics     Aman   Delhi  50000         5   250000
# 1       Phone  Electronics    Rahul  Mumbai  25000         8   200000
# 2      Tablet  Electronics    Priya   Delhi  18000         4    72000
# 3       Mouse  Accessories     Aman  Jaipur    800        20    16000
# 4    Keyboard  Accessories    Rohit  Mumbai   1500        15    22500
# 5     Monitor  Electronics    Rahul   Delhi  12000         6    72000
# 6     Printer       Office    Priya    Pune  10000         3    30000
# 7  Headphones  Accessories     Neha  Jaipur   2500        10    25000
# 8     Speaker  Accessories     Aman   Delhi   3500         7    24500
# 9      Camera  Electronics    Rohit    Pune  40000         2    80000
#
#  Revenue by Category
# -------------------------
# Category
# Accessories     88000
# Electronics    674000
# Office          30000
# Name: Revenue, dtype: int64
#
#  Revenue By City
# -------------------------
# City
# Delhi     418500
# Jaipur     41000
# Mumbai    222500
# Pune      110000
# Name: Revenue, dtype: int64
#
#  Revenue by Customers
# -------------------------
# Customer
# Aman     290500
# Neha      25000
# Priya    102000
# Rahul    272000
# Rohit    102500
# Name: Revenue, dtype: int64
#
# Product count by category
# -------------------------
# Category
# Accessories    4
# Electronics    5
# Office         1
# Name: Product, dtype: int64
#
#  Orders per City
# -------------------------
# City
# Delhi     4
# Jaipur    2
# Mumbai    2
# Pune      2
# Name: Product, dtype: int64

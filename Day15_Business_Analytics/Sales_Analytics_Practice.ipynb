# %%
import pandas as pd

data = {
    "Product": [
        "Laptop", "Phone", "Tablet", "Mouse", "Keyboard",
        "Monitor", "Printer", "Headphones", "Speaker", "Camera"
    ],

    "Category": [
        "Electronics", "Electronics", "Electronics", "Accessories",
        "Accessories", "Electronics", "Office", "Accessories",
        "Accessories", "Electronics"
    ],

    "Price": [
        50000, 25000, 18000, 800, 1500,
        12000, 10000, 2500, 3500, 40000
    ],

    "Quantity": [
        5, 8, 4, 20, 15,
        6, 3, 10, 7, 2
    ]
}

df = pd.DataFrame(data)
print(" Sales Data ")
print(df)


df["Revenue"] = df["Quantity"] * df["Price"]
print("\n Calculate Revenue")
print(df[["Product","Revenue"]])

print("\nHighest Revenue Product")
print(df.loc[df["Revenue"].idxmax()])

print("\nLowest Revenue Product")
print(df.loc[df["Revenue"].idxmin()])

print("\nTotal Revenue")
print("Total revenue generated are : ", df["Revenue"].sum())

print("\nAverage Revenue")
print("Average Revenue =", df["Revenue"].mean())
# Out:
#  Sales Data
#       Product     Category  Price  Quantity
# 0      Laptop  Electronics  50000         5
# 1       Phone  Electronics  25000         8
# 2      Tablet  Electronics  18000         4
# 3       Mouse  Accessories    800        20
# 4    Keyboard  Accessories   1500        15
# 5     Monitor  Electronics  12000         6
# 6     Printer       Office  10000         3
# 7  Headphones  Accessories   2500        10
# 8     Speaker  Accessories   3500         7
# 9      Camera  Electronics  40000         2
#
#  Calculate Revenue
#       Product  Revenue
# 0      Laptop   250000
# 1       Phone   200000
# 2      Tablet    72000
# 3       Mouse    16000
# 4    Keyboard    22500
# 5     Monitor    72000
# 6     Printer    30000
# 7  Headphones    25000
# 8     Speaker    24500
# 9      Camera    80000
#
# Highest Revenue Product
# Product          Laptop
# Category    Electronics
# Price             50000
# Quantity              5
# Revenue          250000
# Name: 0, dtype: object
#
# Lowest Revenue Product
# Product           Mouse
# Category    Accessories
# Price               800
# Quantity             20
# Revenue           16000
# Name: 3, dtype: object
#
# Total Revenue
# Total revenue generated are :  792000
#
# Average Revenue
# Average Revenue = 79200.0

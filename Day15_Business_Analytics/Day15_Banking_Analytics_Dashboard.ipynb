# %%
import pandas as pd

data = {
    "Customer": [
        "Aman", "Rahul", "Priya", "Neha", "Rohit",
        "Simran", "Karan", "Anjali", "Vikas", "Pooja",
        "Arjun", "Sneha", "Raj", "Meera", "Akash"
    ],

    "Account_Type": [
        "Savings", "Current", "Savings", "Current", "Savings",
        "Current", "Savings", "Current", "Savings", "Savings",
        "Current", "Savings", "Current", "Savings", "Current"
    ],

    "Balance": [
        50000, 120000, 75000, 150000, 65000,
        200000, 90000, 110000, 45000, 85000,
        175000, 95000, 130000, 70000, 160000
    ],

    "City": [
        "Delhi", "Mumbai", "Delhi", "Bangalore", "Jaipur",
        "Mumbai", "Pune", "Delhi", "Jaipur", "Pune",
        "Bangalore", "Mumbai", "Delhi", "Pune", "Bangalore"
    ]
}

df = pd.DataFrame(data)
print("="*45)
print("        Banking Analytics Dashboard")
print("="*45)
print(df)

print("\n---- Total Customers ----")
print("Total Customers are : ", df["Customer"].count())

print("\n---- Total Balance ----")
print("Total Balance are : ",df["Balance"].sum())

print("\n---- Average balance ----")
print("Average Balance are : ", df["Balance"].mean())

print("\n---- Richest Customer ----")
print(df.loc[df["Balance"].idxmax()])

print("\n---- Balance By city ----")
print(df.groupby("City")["Balance"].sum())

print("\n----  Balance by Account Type ----")
print(df.groupby("Account_Type")["Balance"].sum())

print("\n")
print("="*45)
print("            End of Dashboard")
print("="*45)
# Out:
# =============================================
#         Banking Analytics Dashboard
# =============================================
#    Customer Account_Type  Balance       City
# 0      Aman      Savings    50000      Delhi
# 1     Rahul      Current   120000     Mumbai
# 2     Priya      Savings    75000      Delhi
# 3      Neha      Current   150000  Bangalore
# 4     Rohit      Savings    65000     Jaipur
# 5    Simran      Current   200000     Mumbai
# 6     Karan      Savings    90000       Pune
# 7    Anjali      Current   110000      Delhi
# 8     Vikas      Savings    45000     Jaipur
# 9     Pooja      Savings    85000       Pune
# 10    Arjun      Current   175000  Bangalore
# 11    Sneha      Savings    95000     Mumbai
# 12      Raj      Current   130000      Delhi
# 13    Meera      Savings    70000       Pune
# 14    Akash      Current   160000  Bangalore
#
# ---- Total Customers ----
# Total Customers are :  15
#
# ---- Total Balance ----
# Total Balance are :  1620000
#
# ---- Average balance ----
# Average Balance are :  108000.0
#
# ---- Richest Customer ----
# Customer         Simran
# Account_Type    Current
# Balance          200000
# City             Mumbai
# Name: 5, dtype: object
#
# ---- Balance By city ----
# City
# Bangalore    485000
# Delhi        365000
# Jaipur       110000
# Mumbai       415000
# Pune         245000
# Name: Balance, dtype: int64
#
# ----  Balance by Account Type ----
# Account_Type
# Current    1045000
# Savings     575000
# Name: Balance, dtype: int64
#
#
# =============================================
#             End of Dashboard
# =============================================

# %%
import pandas as pd

data = {
    "Product": [
        "Laptop", "Phone", "Tablet", "Mouse", "Keyboard",
        "Monitor", "Printer", "Laptop", "Phone", "Tablet"
    ],

    "Category": [
        "Electronics", "Electronics", "Electronics",
        "Accessories", "Accessories",
        "Electronics", "Office", "Electronics",
        "Electronics", "Electronics"
    ],

    "City": [
        "Delhi", "Mumbai", "Delhi", "Lucknow", "Mumbai",
        "Delhi", "Jaipur", "Lucknow", "Jaipur", "Mumbai"
    ],

    "Customer": [
        "Aman", "Rahul", "Priya", "Neha", "Rohit",
        "Simran", "Karan", "Pooja", "Vikas", "Anjali"
    ],

    "Price": [
        50000, 25000, 18000, 800, 1500,
        12000, 10000, 50000, 25000, 18000
    ],

    "Quantity": [
        5, 8, 4, 20, 15,
        6, 3, 2, 7, 5
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Product     Category     City Customer  Price  Quantity
# 0    Laptop  Electronics    Delhi     Aman  50000         5
# 1     Phone  Electronics   Mumbai    Rahul  25000         8
# 2    Tablet  Electronics    Delhi    Priya  18000         4
# 3     Mouse  Accessories  Lucknow     Neha    800        20
# 4  Keyboard  Accessories   Mumbai    Rohit   1500        15
# 5   Monitor  Electronics    Delhi   Simran  12000         6
# 6   Printer       Office   Jaipur    Karan  10000         3
# 7    Laptop  Electronics  Lucknow    Pooja  50000         2
# 8     Phone  Electronics   Jaipur    Vikas  25000         7
# 9    Tablet  Electronics   Mumbai   Anjali  18000         5

# %%
# Revenue Calculations

df["Revenue"]= df["Price"] * df["Quantity"]
print(df)
# Out:
#     Product     Category     City Customer  Price  Quantity  Revenue
# 0    Laptop  Electronics    Delhi     Aman  50000         5   250000
# 1     Phone  Electronics   Mumbai    Rahul  25000         8   200000
# 2    Tablet  Electronics    Delhi    Priya  18000         4    72000
# 3     Mouse  Accessories  Lucknow     Neha    800        20    16000
# 4  Keyboard  Accessories   Mumbai    Rohit   1500        15    22500
# 5   Monitor  Electronics    Delhi   Simran  12000         6    72000
# 6   Printer       Office   Jaipur    Karan  10000         3    30000
# 7    Laptop  Electronics  Lucknow    Pooja  50000         2   100000
# 8     Phone  Electronics   Jaipur    Vikas  25000         7   175000
# 9    Tablet  Electronics   Mumbai   Anjali  18000         5    90000

# %%
#Total Revenue

print("Total Revenue is : ", df["Revenue"].sum())
# Out:
# Total Revenue is :  1027500

# %%
#Top Products

print(df.sort_values(by="Revenue",ascending= False))
# Out:
#     Product     Category     City Customer  Price  Quantity  Revenue
# 0    Laptop  Electronics    Delhi     Aman  50000         5   250000
# 1     Phone  Electronics   Mumbai    Rahul  25000         8   200000
# 8     Phone  Electronics   Jaipur    Vikas  25000         7   175000
# 7    Laptop  Electronics  Lucknow    Pooja  50000         2   100000
# 9    Tablet  Electronics   Mumbai   Anjali  18000         5    90000
# 2    Tablet  Electronics    Delhi    Priya  18000         4    72000
# 5   Monitor  Electronics    Delhi   Simran  12000         6    72000
# 6   Printer       Office   Jaipur    Karan  10000         3    30000
# 4  Keyboard  Accessories   Mumbai    Rohit   1500        15    22500
# 3     Mouse  Accessories  Lucknow     Neha    800        20    16000

# %%
#Top 3 Products

print(df.sort_values(by = "Revenue", ascending = False).head(3))
# Out:
#   Product     Category    City Customer  Price  Quantity  Revenue
# 0  Laptop  Electronics   Delhi     Aman  50000         5   250000
# 1   Phone  Electronics  Mumbai    Rahul  25000         8   200000
# 8   Phone  Electronics  Jaipur    Vikas  25000         7   175000

# %%
#Category Analysis

print(df.groupby("Category")["Revenue"].sum())
# Out:
# Category
# Accessories     38500
# Electronics    959000
# Office          30000
# Name: Revenue, dtype: int64

# %%
#City Wise Sales

print(df.groupby("City")["Revenue"].sum())
# Out:
# City
# Delhi      394000
# Jaipur     205000
# Lucknow    116000
# Mumbai     312500
# Name: Revenue, dtype: int64

# %%
#Top Customers

print(df.groupby("Customer")["Revenue"].sum().sort_values(ascending=False).head(3)
     )
# Out:
# Customer
# Aman     250000
# Rahul    200000
# Vikas    175000
# Name: Revenue, dtype: int64

# %%
# Best Selling Product (By Quantity)

print(
    df.groupby("Product")["Quantity"]
      .sum()
      .sort_values(ascending=False)
)
# Out:
# Product
# Mouse       20
# Phone       15
# Keyboard    15
# Tablet       9
# Laptop       7
# Monitor      6
# Printer      3
# Name: Quantity, dtype: int64

# %%
#Most Expensive Product

print(
    df.loc[df["Price"].idxmax()]
)
# Out:
# Product          Laptop
# Category    Electronics
# City              Delhi
# Customer           Aman
# Price             50000
# Quantity              5
# Revenue          250000
# Name: 0, dtype: object

# %%
#Cheapest Product

print(
    df.loc[df["Price"].idxmin()]
)
# Out:
# Product           Mouse
# Category    Accessories
# City            Lucknow
# Customer           Neha
# Price               800
# Quantity             20
# Revenue           16000
# Name: 3, dtype: object

# %%
a = int(input("entered the value of a is "))
b = int(input("entered the value of b is "))

if a>b:
    print("a is Largest")
else :
    print("b is largest")
# Out:
# entered the value of a is  435
# entered the value of b is  433
# a is Largest

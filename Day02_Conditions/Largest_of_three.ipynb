# %%
a = int(input("entered the value of a is "))
b = int(input("entered the value of b is "))
c = int(input("entered the value of c is "))
if a>=b and a>=c:
    print("Largest no. is a=",a)
elif b>=a and b>=c :
    print("largest no. is b=",b)
else: 
    print("largest no. is c=",c)
# Out:
# entered the value of a is  54
# entered the value of b is  34
# entered the value of c is  23
# Largest no. is a= 54

# %%
a = int(input("entered the value of a is "))
b = int(input("entered the value of b is "))
c = int(input("entered the value of c is "))

print("largest no. is :", max(a,b,c))
# Out:
# entered the value of a is  23
# entered the value of b is  12
# entered the value of c is  234
# largest no. is : 234

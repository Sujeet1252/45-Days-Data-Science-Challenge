# %%
a = int(input("entered the value of a is "))
if a==0:
    print("number is zero")
elif a> 0:
    print("Number is Positive")
else :
    print("number is Negative")
# Out:
# entered the value of a is  -15
# number is Negative

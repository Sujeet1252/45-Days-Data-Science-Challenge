# %%
a = int(input("entered the value of a is "))
if a==0:
    print("number is zero")
elif a%2== 0:
    print("Number is Even")
else :
    print("number is odd")
# Out:
# entered the value of a is  23
# number is odd

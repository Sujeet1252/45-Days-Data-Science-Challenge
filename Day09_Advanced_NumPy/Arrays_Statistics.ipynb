# %%
import numpy as np

print("Random Numbers ")
arr = np.random.randint(1,200,100)
print(arr)

print("\n=== Statistics ===")
print("Maximum Number is : ", np.max(arr))
print("Minimum Number is : ", np.min(arr))
print("Average of Number is : ", np.mean(arr))
# Out:
# Random Numbers
# [104 191  57 146 116 133  42 139 102 193  16 172  74   6 134  74  67 115
#  133 118 114 162 122 186 125   1  48  52  95  72 153 133 169 110 195 184
#   20  31 150  68 193   1 122 173  96 150 190 170  67 153 184 181  62 115
#   61 127   5  28  40 101 185 113 126 193  81 161 101 111  26 131 168 116
#   67 112  52  51   1  81  23 138  84  97 100  19 145  98 107 179 131 164
#  160  44 124   6 109 179 125  74 174   3]
#
# === Statistics ===
# Maximum Number is :  195
# Minimum Number is :  1
# Average of Number is :  107.0

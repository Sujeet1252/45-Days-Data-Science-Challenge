# %% [markdown]
# # Support Vector Machine

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv("placement (1).csv")
dataset.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="cgpa",y="iq",data=dataset,hue="placement")
plt.show()

# %%
x = dataset[["cgpa","iq"]]

y = dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(
    x,
    y,
    random_state =32,
    test_size = 0.2
)

# %%
from sklearn.svm import SVC

sv = SVC(kernel="linear")
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sv.score(x_test,y_test)*100
# Out:
# 90.0

# %%
sv.score(x_train,y_train) * 100
# Out:
# 91.25

# %%
plot_decision_regions(X = x.to_numpy,y = y.to_numpy,clf=sv)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plot_decision_regions(X = x.to_numpy,y = y.to_numpy,clf=sv)
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:160, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#      49 def plot_decision_regions(
#      50     X,
#      51     y,
#    (...)     71     n_jobs=None,
#      72 ):
#      73     """Plot decision regions of a classifier.
#      74
#      75     Please note that this functions assumes that class labels are
#    (...)    157
#     158     """
# --> 160     check_Xy(X, y, y_int=True)  # Validate X and y arrays
#     161     dim = X.shape[1]
#     163     if n_jobs is None:
#
# File ~\anaconda3\Lib\site-packages\mlxtend\utils\checking.py:15, in check_Xy(X, y, y_int)
#      12 def check_Xy(X, y, y_int=True):
#      13     # check types
#      14     if not isinstance(X, np.ndarray):
# ---> 15         raise ValueError("X must be a NumPy array. Found %s" % type(X))
#      16     if not isinstance(y, np.ndarray):
#      17         raise ValueError("y must be a NumPy array. Found %s" % type(y))
#
# ValueError: X must be a NumPy array. Found <class 'method'>

# %%
list = [12,14,56,54,23,56,78,94,25,36,89,74,18,29,35,24]

print(len(list))

print("Original list is :", list)

new_list = list

new_list.sort(reverse=True)

print("\n")

print("Sorted  List  is : ", new_list)
# Out:
# 16
# Original list is : [12, 14, 56, 54, 23, 56, 78, 94, 25, 36, 89, 74, 18, 29, 35, 24]
#
#
# Sorted  List  is :  [94, 89, 78, 74, 56, 56, 54, 36, 35, 29, 25, 24, 23, 18, 14, 12]

# %%
numbers = [40, 10, 30, 20, 50]

new_list = sorted(numbers, reverse=True)

print("Sorted List:", new_list)
print("Original List:", numbers)
# Out:
# Sorted List: [50, 40, 30, 20, 10]
# Original List: [40, 10, 30, 20, 50]

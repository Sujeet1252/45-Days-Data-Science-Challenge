# %%
list = [21, 54, 5, 4, 8, 14 , 63, 56, 87 , 65]


print("list is : ",list )
print("\n")
print("Length of List is :", len(list))
# Out:
# list is :  [21, 54, 5, 4, 8, 14, 63, 56, 87, 65]
#
#
# Length of List is : 10

# %%
list1 = [10, 20, 30]
list2 = [40, 50, 60]

merged_list = list1 + list2

print(merged_list)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 = [10, 20, 30]
list2 = [40, 50, 60]

list1.extend(list2)

print(list1)
# Out:
# [10, 20, 30, 40, 50, 60]

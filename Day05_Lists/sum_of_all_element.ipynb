# %%
numbers = [10, 20, 30, 40, 50]

total = sum(numbers)

print("Sum =", total)
# Out:
# Sum = 150

# %%
numbers = [10, 20, 30, 40, 50]

total = 0

for num in numbers:
    total += num

print("sum is : ",total)
# Out:
# sum is :  150
